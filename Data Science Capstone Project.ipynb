# %% [markdown]
# # Opening a Bike Shop in North York, Toronto

# %% [markdown]
# ## Introduction/Business Problem

# %% [markdown]
# The owners of a bike shop are looking to expand their business and open up another location. They are interested in opening up their next location in a neighbourhood within Toronto's borough of North York. They would like to know which North York neighbourhood would be an ideal location for their next bike shop.
#
# They owners interested in neighbourhoods where their target customer lives and where the neighbourhood isn't already saturated with bike shops. Their target customer are people who are active and live a healthy lifestyle, meaning they go to the park, play sports and/or go the gym.

# %% [markdown]
# ## Data

# %% [markdown]
# In order to recommend a neighbourhood in Toronto's borough of North York where the residents are active and living a healthy lifestyle, I will need the following:
# 1. Data that identifies the boroughs within North York. I will obtain this from the Wikipedia page, https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M. This will provide me with the postal codes and broughs within Toronto as well as the neighbourhoods within each borough. I will use this to identify the neighbourhoods within North York. For example, postal code M2H is a North York borough that is for the Hillcrest Village neighbourhood.
# 2. Location data that identifies the different types of venues already in the boroughs of North York. I will use the Foursquare location data to identify these venues. For example, which neighbourhoods in North York are already populated with bike shops and which neighbourhoods have residents that are active meaning there are other venues such as gyms, parks and sports in the neighbourhood that would likely be used by bicycle riders.

# %% [markdown]
# ## Methodology

# %% [markdown]
# I will focus on identifying neighbourhoods in North York that don't already have a bike shop but have venues that support an active and healthy lifestyle.
#
# After importing and structuring the data, I will identify the neighbourhoods within North York. I will then incorporate the venues within these neighbourhoods and classify the venues to determine which venues would be used by people who are living an active and healthy lifestyle. I will remove neighbourhoods that already have bike shops and/or do not have any venues that support an active and healthy lifestyle.
#
# I will then take the remaining neighbourhoods and cluster them to see which neighbourhoods have the potential to support a bike shop as per the owner's requirements of looking for neighbourhood where the market is not already saturated. Meaning, the neighbourhood has enough venues that is established but not too many venues that the neighbourhood is already overrun with venues.

# %% [markdown]
# #### Import libraries and packages

# %%
import pandas as pd
import numpy as np
import json
from geopy.geocoders import Nominatim
import requests
from pandas.io.json import json_normalize
import matplotlib.cm as cm
import matplotlib.colors as colors
from sklearn.cluster import KMeans
# !pip install folium
import folium
# Out:
# Collecting folium
#   Downloading folium-0.12.1-py2.py3-none-any.whl (94 kB)
#      |████████████████████████████████| 94 kB 6.5 MB/s  eta 0:00:01
# Requirement already satisfied: requests in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.24.0)
# Collecting branca>=0.3.0
#   Downloading branca-0.4.2-py3-none-any.whl (24 kB)
# Requirement already satisfied: numpy in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (1.18.5)
# Requirement already satisfied: jinja2>=2.9 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from folium) (2.11.2)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2.9)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from requests->folium) (1.25.9)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/envs/Python-3.7-main/lib/python3.7/site-packages (from jinja2>=2.9->folium) (1.1.1)
# Installing collected packages: branca, folium
# Successfully installed branca-0.4.2 folium-0.12.1

# %% [markdown]
# #### Scrape neighbourhoods data, layer on latitude and longitude coordinates and setup as a pandas dataframe.

# %%
url = "https://en.wikipedia.org/wiki/List_of_postal_codes_of_Canada:_M"
dfs = pd.read_html(url)
df1 = dfs[0]
df1.drop(df1[df1['Borough']=="Not assigned"].index, inplace = True) 

path = "https://raw.githubusercontent.com/sarahmoakler/Coursera_Capstone/master/Geospatial_Coordinates.csv"
df2 = pd.read_csv(path)
df2

df = df1.merge(df2, on="Postal Code")
NorthYork_df = df[df['Borough']=='North York'].reset_index(drop=True)

# %% [markdown]
# #### Setup Fourquare API credentials (& hide credentials)

# %%
# The code was removed by Watson Studio for sharing.

# %% [markdown]
# #### Create a function to retrieve all the Foursquare venues

# %%
def getNearbyVenues(names, latitudes, longitudes, radius=500):

    venues_list=[]
    for name, lat, lng in zip(names, latitudes, longitudes):
                    
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT)
            
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name, 
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = ['Neighborhood', 
                  'Neighborhood Latitude', 
                  'Neighborhood Longitude', 
                  'Venue', 
                  'Venue Latitude', 
                  'Venue Longitude', 
                  'Venue Category']
    
    return(nearby_venues)

# %% [markdown]
# #### Run function to obtain North York venues

# %%
NorthYork_venues = getNearbyVenues(names=NorthYork_df['Neighbourhood'], 
                                   latitudes=NorthYork_df['Latitude'],
                                   longitudes=NorthYork_df['Longitude'])

# %%
NorthYork_venues
# Out:
#                     Neighborhood  Neighborhood Latitude  \
# 0                      Parkwoods              43.753259
# 1                      Parkwoods              43.753259
# 2                      Parkwoods              43.753259
# 3               Victoria Village              43.725882
# 4               Victoria Village              43.725882
# ..                           ...                    ...
# 241              York Mills West              43.752758
# 242  Willowdale, Willowdale West              43.782736
# 243  Willowdale, Willowdale West              43.782736
# 244  Willowdale, Willowdale West              43.782736
# 245  Willowdale, Willowdale West              43.782736
#
#      Neighborhood Longitude                              Venue  \
# 0                -79.329656                    Brookbanks Park
# 1                -79.329656                      Variety Store
# 2                -79.329656  Corrosion Service Company Limited
# 3                -79.315572             Victoria Village Arena
# 4                -79.315572                          Portugril
# ..                      ...                                ...
# 241              -79.400049   iRemodel Commercial Construction
# 242              -79.442259                             Tov-Li
# 243              -79.442259                 Shoppers Drug Mart
# 244              -79.442259                        Tim Hortons
# 245              -79.442259                      Price Chopper
#
#      Venue Latitude  Venue Longitude              Venue Category
# 0         43.751976       -79.332140                        Park
# 1         43.751974       -79.333114           Food & Drink Shop
# 2         43.752432       -79.334661  Construction & Landscaping
# 3         43.723481       -79.315635                Hockey Arena
# 4         43.725819       -79.312785       Portuguese Restaurant
# ..              ...              ...                         ...
# 241       43.750808       -79.402356  Construction & Landscaping
# 242       43.784214       -79.446098                 Pizza Place
# 243       43.784847       -79.446028                    Pharmacy
# 244       43.780940       -79.444231                 Coffee Shop
# 245       43.783237       -79.446339               Grocery Store
#
# [246 rows x 7 columns]

# %% [markdown]
# #### Determine the venue categories to identify which categories support the active and healthy lifestyle of the bike shop's target customer.

# %%
NorthYork_venues_grouped = NorthYork_venues.groupby('Venue Category').count()[['Venue']].reset_index()
NorthYork_venues_grouped = NorthYork_venues_grouped.sort_values('Venue', ascending=False)
print('The dataframe has ', NorthYork_venues_grouped.shape[0], ' rows and ', NorthYork_venues_grouped.shape[1], ' columns.')
# Out:
# The dataframe has  104  rows and  2  columns.

# %% [markdown]
# Look at the top 60 rows to identify any venues that support the active and healthy lifesytle

# %%
NorthYork_venues_grouped.head(60)
# Out:
#                  Venue Category  Venue
# 29                  Coffee Shop     17
# 28               Clothing Store     13
# 67          Japanese Restaurant      8
# 88                   Restaurant      8
# 79                         Park      8
# 90               Sandwich Place      7
# 8                          Bank      7
# 82                  Pizza Place      7
# 44         Fast Food Restaurant      6
# 23                         Café      5
# 92                Shopping Mall      5
# 55                Grocery Store      5
# 50       Furniture / Home Store      5
# 97             Sushi Restaurant      4
# 69                    Juice Bar      4
# 66           Italian Restaurant      4
# 81                     Pharmacy      4
# 31   Construction & Landscaping      3
# 26           Chinese Restaurant      3
# 91                   Shoe Store      3
# 39               Discount Store      3
# 63               Ice Cream Shop      3
# 93          Sporting Goods Shop      3
# 10               Baseball Field      3
# 56                          Gym      3
# 7                        Bakery      3
# 70                 Liquor Store      3
# 87             Ramen Restaurant      3
# 86                          Pub      2
# 41            Electronics Store      2
# 46                   Food Court      2
# 78                Movie Theater      2
# 77           Miscellaneous Shop      2
# 76    Middle Eastern Restaurant      2
# 68                Jewelry Store      2
# 0             Accessories Store      2
# 12                   Beer Store      2
# 16              Bubble Tea Shop      2
# 2           American Restaurant      2
# 102       Vietnamese Restaurant      2
# 5              Asian Restaurant      2
# 6            Athletics & Sports      2
# 9                           Bar      2
# 14                     Boutique      2
# 32            Convenience Store      2
# 65                 Intersection      2
# 24         Caribbean Restaurant      2
# 95                  Supermarket      2
# 96              Supplement Shop      1
# 100            Toy / Game Store      1
# 83                        Plaza      1
# 101            Video Game Store      1
# 89           Salon / Barbershop      1
# 71                       Lounge      1
# 94                   Steakhouse      1
# 72                Luggage Store      1
# 73               Massage Studio      1
# 74     Mediterranean Restaurant      1
# 75                Metro Station      1
# 84                         Pool      1

# %% [markdown]
# Look at the bottom 60 rows to identify the remaining venues that support the active and healthy lifesytle

# %%
NorthYork_venues_grouped.tail(60)
# Out:
#                Venue Category  Venue
# 32          Convenience Store      2
# 65               Intersection      2
# 24       Caribbean Restaurant      2
# 95                Supermarket      2
# 96            Supplement Shop      1
# 100          Toy / Game Store      1
# 83                      Plaza      1
# 101          Video Game Store      1
# 89         Salon / Barbershop      1
# 71                     Lounge      1
# 94                 Steakhouse      1
# 72              Luggage Store      1
# 73             Massage Studio      1
# 74   Mediterranean Restaurant      1
# 75              Metro Station      1
# 84                       Pool      1
# 99                    Theater      1
# 80                  Pet Store      1
# 98            Thai Restaurant      1
# 85      Portuguese Restaurant      1
# 52                  Gift Shop      1
# 64          Indian Restaurant      1
# 20                   Bus Stop      1
# 34              Deli / Bodega      1
# 33             Cosmetics Shop      1
# 30    Comfort Food Restaurant      1
# 27             Chocolate Shop      1
# 25               Carpet Store      1
# 22                    Butcher      1
# 21           Business Service      1
# 19                Bus Station      1
# 36               Dessert Shop      1
# 18              Burrito Place      1
# 17               Burger Joint      1
# 15                Bridal Shop      1
# 13                  Bike Shop      1
# 11           Basketball Court      1
# 4         Arts & Crafts Store      1
# 3                 Art Gallery      1
# 35           Department Store      1
# 37         Dim Sum Restaurant      1
# 62                      Hotel      1
# 1                     Airport      1
# 61               Home Service      1
# 60               Hockey Arena      1
# 59                 Hobby Shop      1
# 58          Health Food Store      1
# 57       Gym / Fitness Center      1
# 54           Greek Restaurant      1
# 53                Golf Course      1
# 51                Gas Station      1
# 38                      Diner      1
# 49        Fried Chicken Joint      1
# 48          French Restaurant      1
# 47                 Food Truck      1
# 45          Food & Drink Shop      1
# 43         Falafel Restaurant      1
# 42                Event Space      1
# 40                    Dog Run      1
# 103             Women's Store      1

# %% [markdown]
# The following venues would be used by people who live an active and healthy lifestyle: Park, Gym, Juice Bar, Baseball Field, Athletics & Sports, Sporting Goods Shop, Playground, Pool, Supplement Shop, Trail, Basketball Court, Dog Run, and Hockey Arena.
#
# Whereas the Bike Shop venue are existing bike shop locations that we want to avoid as the neighbourhoods that have a bike shop are already saturated.

# %%
venues_to_avoid = ['Bike Shop']
venues_to_be_near = ['Park', 'Gym', 'Juice Bar', 'Baseball Field', 'Athletics & Sports', 'Sporting Goods Shop', 'Playground', 'Pool', 'Supplement Shop', 'Trail', 'Basketball Court', 'Dog Run', 'Hockey Arena']

# %% [markdown]
# #### Merge our categories of venues to avoid and be near into the venues dataframe.

# %%
conditions = [
    (NorthYork_venues['Venue Category'] == venues_to_avoid[0]),
    (NorthYork_venues['Venue Category'].isin(venues_to_be_near)),
    (NorthYork_venues['Venue Category'] != venues_to_avoid[0])
    ]
values = ['Avoid Venue', 'Be Near Venue', 'Indifferent Venue']

NorthYork_venues['Venue Supportability'] = np.select(conditions, values)
NorthYork_venues.head(40)
# Out:
#                         Neighborhood  Neighborhood Latitude  \
# 0                          Parkwoods              43.753259
# 1                          Parkwoods              43.753259
# 2                          Parkwoods              43.753259
# 3                   Victoria Village              43.725882
# 4                   Victoria Village              43.725882
# 5                   Victoria Village              43.725882
# 6                   Victoria Village              43.725882
# 7   Lawrence Manor, Lawrence Heights              43.718518
# 8   Lawrence Manor, Lawrence Heights              43.718518
# 9   Lawrence Manor, Lawrence Heights              43.718518
# 10  Lawrence Manor, Lawrence Heights              43.718518
# 11  Lawrence Manor, Lawrence Heights              43.718518
# 12  Lawrence Manor, Lawrence Heights              43.718518
# 13  Lawrence Manor, Lawrence Heights              43.718518
# 14  Lawrence Manor, Lawrence Heights              43.718518
# 15  Lawrence Manor, Lawrence Heights              43.718518
# 16  Lawrence Manor, Lawrence Heights              43.718518
# 17  Lawrence Manor, Lawrence Heights              43.718518
# 18  Lawrence Manor, Lawrence Heights              43.718518
# 19  Lawrence Manor, Lawrence Heights              43.718518
# 20  Lawrence Manor, Lawrence Heights              43.718518
# 21                         Don Mills              43.745906
# 22                         Don Mills              43.745906
# 23                         Don Mills              43.745906
# 24                         Don Mills              43.745906
# 25                         Glencairn              43.709577
# 26                         Glencairn              43.709577
# 27                         Glencairn              43.709577
# 28                         Glencairn              43.709577
# 29                         Don Mills              43.725900
# 30                         Don Mills              43.725900
# 31                         Don Mills              43.725900
# 32                         Don Mills              43.725900
# 33                         Don Mills              43.725900
# 34                         Don Mills              43.725900
# 35                         Don Mills              43.725900
# 36                         Don Mills              43.725900
# 37                         Don Mills              43.725900
# 38                         Don Mills              43.725900
# 39                         Don Mills              43.725900
#
#     Neighborhood Longitude                                  Venue  \
# 0               -79.329656                        Brookbanks Park
# 1               -79.329656                          Variety Store
# 2               -79.329656      Corrosion Service Company Limited
# 3               -79.315572                 Victoria Village Arena
# 4               -79.315572                              Portugril
# 5               -79.315572                            Tim Hortons
# 6               -79.315572                               The Frig
# 7               -79.464763                                  Roots
# 8               -79.464763  Kitchen Stuff Plus (Clearance Outlet)
# 9               -79.464763         Lac Vien Vietnamese Restaurant
# 10              -79.464763            Orfus Road Shopping Outlets
# 11              -79.464763                            Tim Hortons
# 12              -79.464763                    Ardene Shoes Outlet
# 13              -79.464763         Rinx Real Entertainment Centre
# 14              -79.464763                International Clothiers
# 15              -79.464763                             Suzy Shier
# 16              -79.464763                     Kitchen Stuff Plus
# 17              -79.464763                         Urban Behavior
# 18              -79.464763                 Imperial Carpet & Home
# 19              -79.464763                     Universal Lighting
# 20              -79.464763                             Party City
# 21              -79.352188                           Island Foods
# 22              -79.352188                          Baretto Caffé
# 23              -79.352188                             LA Fitness
# 24              -79.352188                            Gonoe Sushi
# 25              -79.445073     R Bakery - Delicious Cakes, Breads
# 26              -79.445073                Miyako Sushi Restaurant
# 27              -79.445073    Chalker's Pub, Billiards and Bistro
# 28              -79.445073                        Fraserwood Park
# 29              -79.340923                     Sorento Restaurant
# 30              -79.340923                     Fitness Connection
# 31              -79.340923                                 Oomomo
# 32              -79.340923                      Tilley Endurables
# 33              -79.340923                           Swiss Chalet
# 34              -79.340923                       Skiis and Biikes
# 35              -79.340923          Just Hockey Source For Sports
# 36              -79.340923                            Tim Hortons
# 37              -79.340923                      Memories of Japan
# 38              -79.340923      Japanese Canadian Cultural Centre
# 39              -79.340923                         The Beer Store
#
#     Venue Latitude  Venue Longitude              Venue Category  \
# 0        43.751976       -79.332140                        Park
# 1        43.751974       -79.333114           Food & Drink Shop
# 2        43.752432       -79.334661  Construction & Landscaping
# 3        43.723481       -79.315635                Hockey Arena
# 4        43.725819       -79.312785       Portuguese Restaurant
# 5        43.725517       -79.313103                 Coffee Shop
# 6        43.727051       -79.317418           French Restaurant
# 7        43.718214       -79.463893                    Boutique
# 8        43.719096       -79.462675      Furniture / Home Store
# 9        43.721259       -79.468472       Vietnamese Restaurant
# 10       43.719045       -79.460849              Clothing Store
# 11       43.719427       -79.467995                 Coffee Shop
# 12       43.718892       -79.461344           Accessories Store
# 13       43.717842       -79.462231                 Event Space
# 14       43.717997       -79.466720              Clothing Store
# 15       43.718846       -79.465906              Clothing Store
# 16       43.719087       -79.462970      Furniture / Home Store
# 17       43.718899       -79.464695              Clothing Store
# 18       43.716672       -79.467415                Carpet Store
# 19       43.721685       -79.466310      Furniture / Home Store
# 20       43.719418       -79.459317          Miscellaneous Shop
# 21       43.745866       -79.346035        Caribbean Restaurant
# 22       43.744456       -79.346460                        Café
# 23       43.747665       -79.347077                         Gym
# 24       43.745737       -79.345991         Japanese Restaurant
# 25       43.707420       -79.443126                      Bakery
# 26       43.709111       -79.443930         Japanese Restaurant
# 27       43.705747       -79.442378                         Pub
# 28       43.713550       -79.442482                        Park
# 29       43.726575       -79.341989          Italian Restaurant
# 30       43.727473       -79.341707                         Gym
# 31       43.726429       -79.343283              Discount Store
# 32       43.727033       -79.342926              Clothing Store
# 33       43.726747       -79.341625                  Restaurant
# 34       43.726351       -79.342977                   Bike Shop
# 35       43.727095       -79.342591         Sporting Goods Shop
# 36       43.722897       -79.339117                 Coffee Shop
# 37       43.727078       -79.340794         Japanese Restaurant
# 38       43.726429       -79.334971                 Art Gallery
# 39       43.726987       -79.341494                  Beer Store
#
#    Venue Supportability
# 0         Be Near Venue
# 1     Indifferent Venue
# 2     Indifferent Venue
# 3         Be Near Venue
# 4     Indifferent Venue
# 5     Indifferent Venue
# 6     Indifferent Venue
# 7     Indifferent Venue
# 8     Indifferent Venue
# 9     Indifferent Venue
# 10    Indifferent Venue
# 11    Indifferent Venue
# 12    Indifferent Venue
# 13    Indifferent Venue
# 14    Indifferent Venue
# 15    Indifferent Venue
# 16    Indifferent Venue
# 17    Indifferent Venue
# 18    Indifferent Venue
# 19    Indifferent Venue
# 20    Indifferent Venue
# 21    Indifferent Venue
# 22    Indifferent Venue
# 23        Be Near Venue
# 24    Indifferent Venue
# 25    Indifferent Venue
# 26    Indifferent Venue
# 27    Indifferent Venue
# 28        Be Near Venue
# 29    Indifferent Venue
# 30        Be Near Venue
# 31    Indifferent Venue
# 32    Indifferent Venue
# 33    Indifferent Venue
# 34          Avoid Venue
# 35        Be Near Venue
# 36    Indifferent Venue
# 37    Indifferent Venue
# 38    Indifferent Venue
# 39    Indifferent Venue

# %% [markdown]
# #### Group the Venues by our venue supportabilty categories to see how many venues we need to avoid and how many are available to support our bike shop.

# %%
NorthYork_venues_grouped_vs = NorthYork_venues.groupby('Venue Supportability').count()[['Venue']].reset_index()
NorthYork_venues_grouped_vs = NorthYork_venues_grouped_vs.sort_values('Venue', ascending=False)
NorthYork_venues_grouped_vs
# Out:
#   Venue Supportability  Venue
# 2    Indifferent Venue    217
# 1        Be Near Venue     28
# 0          Avoid Venue      1

# %% [markdown]
# #### Obtain North York location coordinates so we can map our venues

# %%
address = 'North York, ON'
geolocator = Nominatim(user_agent="on_explorer")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('Geograpical coordinate of North York is {}, {}'.format(latitude, longitude))
# Out:
# Geograpical coordinate of North York is 43.7543263, -79.44911696639593

# %% [markdown]
# #### Map our venues by our venue supportability to see the neighbourhood potential

# %%
map_NorthYork_venues = folium.Map(location=[latitude, longitude], zoom_start=12)

for lat, lon, ven, vs in zip(NorthYork_venues['Venue Latitude'], NorthYork_venues['Venue Longitude'], NorthYork_venues['Venue'], NorthYork_venues['Venue Supportability']):
    label = folium.Popup(str(ven) + 'Venue Supportability: ' + vs, parse_html=True)
    
    if vs=="Avoid Venue":
        folium.CircleMarker(
            [lat, lon],
            radius=5,
            popup=label,
            color= 'red', 
            fill=True,
            fill_color='red',
            fill_opacity=0.7).add_to(map_NorthYork_venues)

    if vs=="Be Near Venue":
        folium.CircleMarker(
            [lat, lon],
            radius=5,
            popup=label,
            color= 'green', 
            fill=True,
            fill_color='green',
            fill_opacity=0.7).add_to(map_NorthYork_venues)
        
    else:
        folium.CircleMarker(
            [lat, lon],
            radius=5,
            popup=label,
            color= 'grey', 
            fill=True,
            fill_color='grey',
            fill_opacity=0.7).add_to(map_NorthYork_venues)
        
map_NorthYork_venues
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_aabcf3251764455998f7e25bdf128fa0%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_aabcf3251764455998f7e25bdf128fa0%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_aabcf3251764455998f7e25bdf128fa0%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_aabcf3251764455998f7e25bdf128fa0%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.7543263%2C%20-79.44911696639593%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# #### Looks like the neighbourhoods on the Eastern side of North York have venues what would also be visited by the bike shop's target customers.

# %% [markdown]
# #### One hot encode the venue supportability categories so that we can cluster our neighbourhoods by these supportability categories.

# %%
NorthYork_onehot = pd.get_dummies(NorthYork_venues[['Venue Supportability']], prefix="", prefix_sep="")
NorthYork_onehot['Neighbourhood'] = NorthYork_venues['Neighborhood']
fixed_columns = [NorthYork_onehot.columns[-1]] + list(NorthYork_onehot.columns[:-1])
NorthYork_onehot = NorthYork_onehot[fixed_columns]
NorthYork_grouped = NorthYork_onehot.groupby('Neighbourhood').sum().reset_index()
NorthYork_grouped
# Out:
#                                       Neighbourhood  Avoid Venue  \
# 0   Bathurst Manor, Wilson Heights, Downsview North            0
# 1                                   Bayview Village            0
# 2                 Bedford Park, Lawrence Manor East            0
# 3                                         Don Mills            1
# 4                                         Downsview            0
# 5                      Fairview, Henry Farm, Oriole            0
# 6                                         Glencairn            0
# 7                                 Hillcrest Village            0
# 8                                     Humber Summit            0
# 9                                  Humberlea, Emery            0
# 10                 Lawrence Manor, Lawrence Heights            0
# 11         North Park, Maple Leaf Park, Upwood Park            0
# 12                  Northwood Park, York University            0
# 13                                        Parkwoods            0
# 14                                 Victoria Village            0
# 15                          Willowdale, Newtonbrook            0
# 16                      Willowdale, Willowdale East            0
# 17                      Willowdale, Willowdale West            0
# 18                                  York Mills West            0
#
#     Be Near Venue  Indifferent Venue
# 0               1                 19
# 1               0                  4
# 2               1                 23
# 3               4                 19
# 4               4                 11
# 5               6                 65
# 6               1                  3
# 7               3                  3
# 8               0                  2
# 9               1                  0
# 10              0                 14
# 11              2                  2
# 12              0                  8
# 13              1                  2
# 14              1                  3
# 15              1                  0
# 16              1                 33
# 17              0                  4
# 18              1                  2

# %%
print("# Neighbourhoods with venues to be near:", NorthYork_grouped["Be Near Venue"][NorthYork_grouped["Be Near Venue"] !=0].count())
print("# Neighbourhoods with venues to avoid:", NorthYork_grouped["Avoid Venue"][NorthYork_grouped["Avoid Venue"] !=0].count())
# Out:
# # Neighbourhoods with venues to be near: 14
# # Neighbourhoods with venues to avoid: 1

# %% [markdown]
# #### There are 13 neighbourhoods in North York that have venues that the target customer's of the bike shop also use but there is one neighbourhood that already has a bike shop that should be avoided.

# %% [markdown]
# #### Since the bike shop owner's want to avoid neighbourhoods that already have a bike shop and want to target neighbourhoods that have venues supporting an active and healthy lifestyle, I will remove the neighbourhoods that don't meet this criteria.

# %%
NorthYork_grouped.drop(NorthYork_grouped.index[NorthYork_grouped['Avoid Venue'] !=0], inplace=True)
NorthYork_grouped.drop(NorthYork_grouped.index[NorthYork_grouped['Be Near Venue'] ==0], inplace=True)
NorthYork_grouped
# Out:
#                                       Neighbourhood  Avoid Venue  \
# 0   Bathurst Manor, Wilson Heights, Downsview North            0
# 2                 Bedford Park, Lawrence Manor East            0
# 4                                         Downsview            0
# 5                      Fairview, Henry Farm, Oriole            0
# 6                                         Glencairn            0
# 7                                 Hillcrest Village            0
# 9                                  Humberlea, Emery            0
# 11         North Park, Maple Leaf Park, Upwood Park            0
# 13                                        Parkwoods            0
# 14                                 Victoria Village            0
# 15                          Willowdale, Newtonbrook            0
# 16                      Willowdale, Willowdale East            0
# 18                                  York Mills West            0
#
#     Be Near Venue  Indifferent Venue
# 0               1                 19
# 2               1                 23
# 4               4                 11
# 5               6                 65
# 6               1                  3
# 7               3                  3
# 9               1                  0
# 11              2                  2
# 13              1                  2
# 14              1                  3
# 15              1                  0
# 16              1                 33
# 18              1                  2

# %% [markdown]
# #### Cluster the neighbourhoods into 3 clusters and create a new dataframe for the clusters.

# %%
kclusters = 3
NorthYork_grouped_clustering = NorthYork_grouped.drop('Neighbourhood', 1)
kmeans = KMeans(n_clusters=kclusters, random_state=0).fit(NorthYork_grouped_clustering)

# %%
NorthYork_grouped.insert(0, 'Cluster Labels', kmeans.labels_)
NorthYork_grouped
# Out:
#     Cluster Labels                                    Neighbourhood  \
# 0                2  Bathurst Manor, Wilson Heights, Downsview North
# 2                2                Bedford Park, Lawrence Manor East
# 4                0                                        Downsview
# 5                1                     Fairview, Henry Farm, Oriole
# 6                0                                        Glencairn
# 7                0                                Hillcrest Village
# 9                0                                 Humberlea, Emery
# 11               0         North Park, Maple Leaf Park, Upwood Park
# 13               0                                        Parkwoods
# 14               0                                 Victoria Village
# 15               0                          Willowdale, Newtonbrook
# 16               2                      Willowdale, Willowdale East
# 18               0                                  York Mills West
#
#     Avoid Venue  Be Near Venue  Indifferent Venue
# 0             0              1                 19
# 2             0              1                 23
# 4             0              4                 11
# 5             0              6                 65
# 6             0              1                  3
# 7             0              3                  3
# 9             0              1                  0
# 11            0              2                  2
# 13            0              1                  2
# 14            0              1                  3
# 15            0              1                  0
# 16            0              1                 33
# 18            0              1                  2

# %%
NorthYork_merged = NorthYork_df
NorthYork_merged = NorthYork_merged.join(NorthYork_grouped.set_index('Neighbourhood'), on='Neighbourhood')

NorthYork_merged = NorthYork_merged.dropna(subset=['Cluster Labels']).reset_index(drop=True)
NorthYork_merged['Cluster Labels'] = NorthYork_merged['Cluster Labels'].astype(int)
NorthYork_merged['Avoid Venue'] = NorthYork_merged['Avoid Venue'].astype(int)
NorthYork_merged['Be Near Venue'] = NorthYork_merged['Be Near Venue'].astype(int)
NorthYork_merged['Indifferent Venue'] = NorthYork_merged['Indifferent Venue'].astype(int)

# %%
NorthYork_merged
# Out:
#    Postal Code     Borough                                    Neighbourhood  \
# 0          M3A  North York                                        Parkwoods
# 1          M4A  North York                                 Victoria Village
# 2          M6B  North York                                        Glencairn
# 3          M2H  North York                                Hillcrest Village
# 4          M3H  North York  Bathurst Manor, Wilson Heights, Downsview North
# 5          M2J  North York                     Fairview, Henry Farm, Oriole
# 6          M3K  North York                                        Downsview
# 7          M3L  North York                                        Downsview
# 8          M6L  North York         North Park, Maple Leaf Park, Upwood Park
# 9          M2M  North York                          Willowdale, Newtonbrook
# 10         M3M  North York                                        Downsview
# 11         M5M  North York                Bedford Park, Lawrence Manor East
# 12         M9M  North York                                 Humberlea, Emery
# 13         M2N  North York                      Willowdale, Willowdale East
# 14         M3N  North York                                        Downsview
# 15         M2P  North York                                  York Mills West
#
#      Latitude  Longitude  Cluster Labels  Avoid Venue  Be Near Venue  \
# 0   43.753259 -79.329656               0            0              1
# 1   43.725882 -79.315572               0            0              1
# 2   43.709577 -79.445073               0            0              1
# 3   43.803762 -79.363452               0            0              3
# 4   43.754328 -79.442259               2            0              1
# 5   43.778517 -79.346556               1            0              6
# 6   43.737473 -79.464763               0            0              4
# 7   43.739015 -79.506944               0            0              4
# 8   43.713756 -79.490074               0            0              2
# 9   43.789053 -79.408493               0            0              1
# 10  43.728496 -79.495697               0            0              4
# 11  43.733283 -79.419750               2            0              1
# 12  43.724766 -79.532242               0            0              1
# 13  43.770120 -79.408493               2            0              1
# 14  43.761631 -79.520999               0            0              4
# 15  43.752758 -79.400049               0            0              1
#
#     Indifferent Venue
# 0                   2
# 1                   3
# 2                   3
# 3                   3
# 4                  19
# 5                  65
# 6                  11
# 7                  11
# 8                   2
# 9                   0
# 10                 11
# 11                 23
# 12                  0
# 13                 33
# 14                 11
# 15                  2

# %% [markdown]
# #### Visualize the clusters

# %%
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

colors_array = cm.rainbow(np.linspace(0, 1, kclusters))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(NorthYork_merged['Latitude'], NorthYork_merged['Longitude'], NorthYork_merged['Neighbourhood'], NorthYork_merged['Cluster Labels']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster - 1],
        fill=True,
        fill_color=rainbow[cluster - 1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%3Cscript%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20L_NO_TOUCH%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20L_DISABLE_3D%20%3D%20false%3B%0A%20%20%20%20%20%20%20%20%3C/script%3E%0A%20%20%20%20%0A%20%20%20%20%3Cstyle%3Ehtml%2C%20body%20%7Bwidth%3A%20100%25%3Bheight%3A%20100%25%3Bmargin%3A%200%3Bpadding%3A%200%3B%7D%3C/style%3E%0A%20%20%20%20%3Cstyle%3E%23map%20%7Bposition%3Aabsolute%3Btop%3A0%3Bbottom%3A0%3Bright%3A0%3Bleft%3A0%3B%7D%3C/style%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//code.jquery.com/jquery-1.12.4.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js%22%3E%3C/script%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.6.0/dist/leaflet.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css%22/%3E%0A%20%20%20%20%3Clink%20rel%3D%22stylesheet%22%20href%3D%22https%3A//cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css%22/%3E%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cmeta%20name%3D%22viewport%22%20content%3D%22width%3Ddevice-width%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20initial-scale%3D1.0%2C%20maximum-scale%3D1.0%2C%20user-scalable%3Dno%22%20/%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cstyle%3E%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%23map_6fb498fd921f4b719e1d5d5eab649eb6%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20position%3A%20relative%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20width%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20height%3A%20100.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20left%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20top%3A%200.0%25%3B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7D%0A%20%20%20%20%20%20%20%20%20%20%20%20%3C/style%3E%0A%20%20%20%20%20%20%20%20%0A%3C/head%3E%0A%3Cbody%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20%3Cdiv%20class%3D%22folium-map%22%20id%3D%22map_6fb498fd921f4b719e1d5d5eab649eb6%22%20%3E%3C/div%3E%0A%20%20%20%20%20%20%20%20%0A%3C/body%3E%0A%3Cscript%3E%20%20%20%20%0A%20%20%20%20%0A%20%20%20%20%20%20%20%20%20%20%20%20var%20map_6fb498fd921f4b719e1d5d5eab649eb6%20%3D%20L.map%28%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%22map_6fb498fd921f4b719e1d5d5eab649eb6%22%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%7B%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20%20center%3A%20%5B43.7543263%2C%20-79.44911696639593%5D%2C%0A%20%20%20%20%20%20%20%20%20%20%20%20%20%20 ...

# %% [markdown]
# #### Determine the ratio of "Be Near Venue" compared to the total venues in the neighbourhood

# %%
NorthYork_merged['% Be Near Venues of Total Venues'] = NorthYork_merged['Be Near Venue']/(NorthYork_merged['Be Near Venue']+NorthYork_merged['Indifferent Venue'])
NorthYork_merged
# Out:
#    Postal Code     Borough                                    Neighbourhood  \
# 0          M3A  North York                                        Parkwoods
# 1          M4A  North York                                 Victoria Village
# 2          M6B  North York                                        Glencairn
# 3          M2H  North York                                Hillcrest Village
# 4          M3H  North York  Bathurst Manor, Wilson Heights, Downsview North
# 5          M2J  North York                     Fairview, Henry Farm, Oriole
# 6          M3K  North York                                        Downsview
# 7          M3L  North York                                        Downsview
# 8          M6L  North York         North Park, Maple Leaf Park, Upwood Park
# 9          M2M  North York                          Willowdale, Newtonbrook
# 10         M3M  North York                                        Downsview
# 11         M5M  North York                Bedford Park, Lawrence Manor East
# 12         M9M  North York                                 Humberlea, Emery
# 13         M2N  North York                      Willowdale, Willowdale East
# 14         M3N  North York                                        Downsview
# 15         M2P  North York                                  York Mills West
#
#      Latitude  Longitude  Cluster Labels  Avoid Venue  Be Near Venue  \
# 0   43.753259 -79.329656               0            0              1
# 1   43.725882 -79.315572               0            0              1
# 2   43.709577 -79.445073               0            0              1
# 3   43.803762 -79.363452               0            0              3
# 4   43.754328 -79.442259               2            0              1
# 5   43.778517 -79.346556               1            0              6
# 6   43.737473 -79.464763               0            0              4
# 7   43.739015 -79.506944               0            0              4
# 8   43.713756 -79.490074               0            0              2
# 9   43.789053 -79.408493               0            0              1
# 10  43.728496 -79.495697               0            0              4
# 11  43.733283 -79.419750               2            0              1
# 12  43.724766 -79.532242               0            0              1
# 13  43.770120 -79.408493               2            0              1
# 14  43.761631 -79.520999               0            0              4
# 15  43.752758 -79.400049               0            0              1
#
#     Indifferent Venue  % Be Near Venues of Total Venues
# 0                   2                          0.333333
# 1                   3                          0.250000
# 2                   3                          0.250000
# 3                   3                          0.500000
# 4                  19                          0.050000
# 5                  65                          0.084507
# 6                  11                          0.266667
# 7                  11                          0.266667
# 8                   2                          0.500000
# 9                   0                          1.000000
# 10                 11                          0.266667
# 11                 23                          0.041667
# 12                  0                          1.000000
# 13                 33                          0.029412
# 14                 11                          0.266667
# 15                  2                          0.333333

# %%
NorthYork_merged = NorthYork_merged.groupby(['Neighbourhood', '% Be Near Venues of Total Venues'], as_index=False).mean()
NorthYork_merged = NorthYork_merged.sort_values('% Be Near Venues of Total Venues', ascending = False)
NorthYork_merged['% Be Near Venues of Total Venues'] = pd.Series(["{0:.0f}%".format(val * 100) for val in NorthYork_merged['% Be Near Venues of Total Venues']], index = NorthYork_merged.index)
NorthYork_merged
# Out:
#                                       Neighbourhood  \
# 6                                  Humberlea, Emery
# 10                          Willowdale, Newtonbrook
# 5                                 Hillcrest Village
# 7          North Park, Maple Leaf Park, Upwood Park
# 8                                         Parkwoods
# 12                                  York Mills West
# 2                                         Downsview
# 4                                         Glencairn
# 9                                  Victoria Village
# 3                      Fairview, Henry Farm, Oriole
# 0   Bathurst Manor, Wilson Heights, Downsview North
# 1                 Bedford Park, Lawrence Manor East
# 11                      Willowdale, Willowdale East
#
#    % Be Near Venues of Total Venues   Latitude  Longitude  Cluster Labels  \
# 6                              100%  43.724766 -79.532242               0
# 10                             100%  43.789053 -79.408493               0
# 5                               50%  43.803762 -79.363452               0
# 7                               50%  43.713756 -79.490074               0
# 8                               33%  43.753259 -79.329656               0
# 12                              33%  43.752758 -79.400049               0
# 2                               27%  43.741654 -79.497101               0
# 4                               25%  43.709577 -79.445073               0
# 9                               25%  43.725882 -79.315572               0
# 3                                8%  43.778517 -79.346556               1
# 0                                5%  43.754328 -79.442259               2
# 1                                4%  43.733283 -79.419750               2
# 11                               3%  43.770120 -79.408493               2
#
#     Avoid Venue  Be Near Venue  Indifferent Venue
# 6             0              1                  0
# 10            0              1                  0
# 5             0              3                  3
# 7             0              2                  2
# 8             0              1                  2
# 12            0              1                  2
# 2             0              4                 11
# 4             0              1                  3
# 9             0              1                  3
# 3             0              6                 65
# 0             0              1                 19
# 1             0              1                 23
# 11            0              1                 33

# %% [markdown]
# ####

# %% [markdown]
# #### Assess the Clusters

# %%
NorthYork_merged.loc[NorthYork_merged['Cluster Labels'] == 0]
# Out:
#                                Neighbourhood % Be Near Venues of Total Venues  \
# 6                           Humberlea, Emery                             100%
# 10                   Willowdale, Newtonbrook                             100%
# 5                          Hillcrest Village                              50%
# 7   North Park, Maple Leaf Park, Upwood Park                              50%
# 8                                  Parkwoods                              33%
# 12                           York Mills West                              33%
# 2                                  Downsview                              27%
# 4                                  Glencairn                              25%
# 9                           Victoria Village                              25%
#
#      Latitude  Longitude  Cluster Labels  Avoid Venue  Be Near Venue  \
# 6   43.724766 -79.532242               0            0              1
# 10  43.789053 -79.408493               0            0              1
# 5   43.803762 -79.363452               0            0              3
# 7   43.713756 -79.490074               0            0              2
# 8   43.753259 -79.329656               0            0              1
# 12  43.752758 -79.400049               0            0              1
# 2   43.741654 -79.497101               0            0              4
# 4   43.709577 -79.445073               0            0              1
# 9   43.725882 -79.315572               0            0              1
#
#     Indifferent Venue
# 6                   0
# 10                  0
# 5                   3
# 7                   2
# 8                   2
# 12                  2
# 2                  11
# 4                   3
# 9                   3

# %%
NorthYork_merged.loc[NorthYork_merged['Cluster Labels'] == 1]
# Out:
#                   Neighbourhood % Be Near Venues of Total Venues   Latitude  \
# 3  Fairview, Henry Farm, Oriole                               8%  43.778517
#
#    Longitude  Cluster Labels  Avoid Venue  Be Near Venue  Indifferent Venue
# 3 -79.346556               1            0              6                 65

# %%
NorthYork_merged.loc[NorthYork_merged['Cluster Labels'] == 2]
# Out:
#                                       Neighbourhood  \
# 0   Bathurst Manor, Wilson Heights, Downsview North
# 1                 Bedford Park, Lawrence Manor East
# 11                      Willowdale, Willowdale East
#
#    % Be Near Venues of Total Venues   Latitude  Longitude  Cluster Labels  \
# 0                                5%  43.754328 -79.442259               2
# 1                                4%  43.733283 -79.419750               2
# 11                               3%  43.770120 -79.408493               2
#
#     Avoid Venue  Be Near Venue  Indifferent Venue
# 0             0              1                 19
# 1             0              1                 23
# 11            0              1                 33

# %% [markdown]
# ## Results

# %% [markdown]
# Cluster 1 contains one neighbourhood, "Fairview, Henry Farm, Oriole", which is a neighbourhood which has the maximum number of "Be Near Venues" but there are a lot of venues which means the market is saturated.
#
# Cluster 2 has three neighbourhoods that have the minimum number of "Be Near Venues" but there are a significant number of other venues saturating the market in these neighbourhoods, so the market is still saturated in these neighbourhoods.
#
#
# Cluster 1 contains neighbourhoods where the majority of the venues in the neighbourhood are those that support an active and healthy lifestyle. Any of these neighbourhoods would be sufficient.

# %% [markdown]
# ## Discussion

# %% [markdown]
# My analysis shows that there are 12 possible neighbourhoods within North York's 19 neighbourhoods that meet the bike owner's criteria for their next bike shop location. These 12 neighbourhoods do not currently contain a bike shop and they all contain venues that support an active and healthy lifestyle they include venues such as a Park, Gym, Juice Bar, Baseball Field, Athletics & Sports, Sporting Goods Shop, Playground, Pool, Supplement Shop, Trail, Basketball Court, Dog Run, and Hockey Arena. These venues are used by their target customer and thus indicate their customers live close to their potential new location.
#
# Of the 12 possible neighbourhoods meeting the criteria for the bike shop, there are only 9 that don't exist in saturated markets. The 9 neighbourhoods in cluster 1 meet all selection criteria provided by the bike shop owners and are neighbourhoods that aren't saturated with too many venues yet.
#
#
# Of the 9 neighbourhoods, I would recommend the neighbourhood "Downsview" for the next bike shop location as this neighbourhood has the maximum number of potential venues that support the active and healthy lifestyle, there are no other bike shops in this neighbourhood and the market is not saturated with venues already.

# %% [markdown]
# ## Conclusion

# %% [markdown]
# The objective of this report was to identify neighbourhoods in Toronto's borough of North York that could support a bicycle shop. By calculating the percentage of venues that already support an an active and healthy lifestyle of all the venues in a neighbourhood, I have identified general neighbourhoods that have residents that are likely to become customers of a bicycle shop. Clustering these neighbourhoods helps to determine which neighbourhoods can support another business from neighbourhoods that already contain a lot of businesses and thus the bicycle shop would have a more difficult time standing out amongst all the other businesses in the neighbourhood.
#
# There are other factors to still consider when picking the neighbourhood, such as do the roads in the neighbourhood contain bicycle lanes, and which exact location within the neighbourhood can easily be accessed and found by customers.
